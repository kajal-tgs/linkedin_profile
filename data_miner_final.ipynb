# %%
#Basic to open chrome-
from selenium import webdriver

from selenium.webdriver.chrome.service import Service
import time
chromedriver_path = "/usr/bin/chromedriver"  
service = Service(executable_path=chromedriver_path)
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.get("https://www.google.com")
time.sleep(20)

driver.quit()

# %%
#for the search query-
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import time

chromedriver_path = "/usr/bin/chromedriver"
service = Service(executable_path=chromedriver_path)
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.get("https://www.google.com/")
search_box = driver.find_element("name", "q")
search_box.send_keys('Salesforce Developer india opentowork "gmail com" site:linkedin.com 1..100')
search_box.send_keys(Keys.RETURN)
time.sleep(15)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
chromedriver_path = "/usr/bin/chromedriver"
extension_path = "datascraper.crx"
options = webdriver.ChromeOptions()
options.add_extension(extension_path)
service = Service(executable_path=chromedriver_path)
driver = webdriver.Chrome(service=service, options=options)
driver.get("https://www.google.com/")
search_box = driver.find_element("name", "q")
search_box.send_keys('Salesforce Developer india opentowork "gmail com" site:linkedin.com 1..100')
search_box.send_keys(Keys.RETURN)
time.sleep(15)

# Right-click on the page
action_chains = ActionChains(driver)
action_chains.context_click().perform()

# Click on "Data Miner" from the context menu (assuming it's the second option, change index if needed)
action_chains.move_by_offset(0, 50).click().perform()

# Wait for some time to see the result (adjust as needed)
time.sleep(5)

# Close the browser
#driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[3], line 20
#      18 # Right-click on the page
#      19 action_chains = ActionChains(driver)
# ---> 20 action_chains.context_click().perform()
#      22 # Click on "Data Miner" from the context menu (assuming it's the second option, change index if needed)
#      23 action_chains.move_by_offset(0, 50).click().perform()
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/common/action_chains.py:94, in ActionChains.perform(self)
#      92 def perform(self) -> None:
#      93     """Performs all stored actions."""
# ---> 94     self.w3c_actions.perform()
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/common/actions/action_builder.py:96, in ActionBuilder.perform(self)
#      94         enc["actions"].append(encoded)
#      95         device.actions = []
# ---> 96 self.driver.execute(Command.W3C_ACTIONS, enc)
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=119.0.6045.199)
# Stacktrace:
# #0 0x560521680463 <unknown>
# #1 0x560521352247 <unknown>
# #2 0x5605213268b8 <unknown>
# #3 0x5605213cb8df <unknown>
# #4 0x5605213e12a6 <unknown>
# #5 0x5605213c5f43 <unknown>
# #6 0x5605213917f3 <unknown>
# #7 0x56052139279e <unknown>
# #8 0x56052164a20a <unknown>
# #9 0x56052164dff4 <unknown>
# #10 0x560521639852 <unknown>
# #11 0x56052164ea10 <unknown>
# #12 0x56052161fbde <unknown>
# #13 0x56052166ecf8 <unknown>
# #14 0x56052166eeea <unknown>
# #15 0x56052167f588 <unknown>
# #16 0x7f3c2b654b43 <unknown>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
chromedriver_path = "/usr/bin/chromedriver"
data_miner_extension_path = "datascraper.crx"

# Set up Chrome options
options = Options()
options.add_extension(data_miner_extension_path)

# Set up the ChromeDriver service
service = Service(executable_path=chromedriver_path)

# Create a WebDriver instance
driver = webdriver.Chrome(service=service, options=options)

# Open Google's homepage
driver.get("https://www.google.com/")

# Find the search input element by name
search_box = driver.find_element("name", "q")

# Enter your search query
search_box.send_keys('Salesforce Developer india opentowork "gmail com" site:linkedin.com 1..100')

# Press the Enter key
search_box.send_keys(Keys.RETURN)

# Wait for the results to load (adjust the sleep duration as needed)
time.sleep(15)

# Close the browser
#driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time

chromedriver_path = "/usr/bin/chromedriver"
data_miner_extension_path = "datascraper.crx"


# Set up Chrome options
options = Options()
options.add_extension(data_miner_extension_path)

# Set up the ChromeDriver service
service = Service(executable_path=chromedriver_path)

# Create a WebDriver instance
driver = webdriver.Chrome(service=service, options=options)
# Open Google's homepage
driver.get("https://www.google.com/")

# Find the search input element by name
search_box = driver.find_element("name", "q")

# Enter your search query
search_box.send_keys('Salesforce Developer india opentowork "gmail com" site:linkedin.com 1..100')

# Press the Enter key
search_box.send_keys(Keys.RETURN)

# Wait for the results to load (adjust the sleep duration as needed)
time.sleep(15)

# Switch to the first search result page
first_result = driver.find_element_by_css_selector('h3')
first_result.click()

# Now you are on the first search result page

# Optionally, you can wait for some time or perform other actions on the page

# Close the browser
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 35
#      32 time.sleep(15)
#      34 # Switch to the first search result page
# ---> 35 first_result = driver.find_element_by_css_selector('h3')
#      36 first_result.click()
#      38 # Now you are on the first search result page
#      39
#      40 # Optionally, you can wait for some time or perform other actions on the page
#      41
#      42 # Close the browser
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_css_selector'

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time

chromedriver_path = "/usr/bin/chromedriver"
data_miner_extension_path = "datascraper.crx"

# Set up Chrome options
options = Options()
options.add_extension(data_miner_extension_path)

# Set up the ChromeDriver service
service = Service(executable_path=chromedriver_path)

# Create a WebDriver instance
driver = webdriver.Chrome(service=service, options=options)
# Open Google's homepage
original_tab = driver.get("https://www.google.com/")

# Find the search input element by name
search_box = driver.find_element("name", "q")

# Enter your search query
search_box.send_keys('Salesforce Developer india opentowork "gmail com" site:linkedin.com 1..100')

# Press the Enter key
search_box.send_keys(Keys.RETURN)

# Wait for the results to load (adjust the sleep duration as needed)
time.sleep(15)

# Store the handle of the original tab
#original_tab = driver.current_window_handle

# Perform actions in the new tab opened by Data Miner extension
# ...

# Switch back to the original tab
driver.switch_to.window(original_tab)

# Now you are back in the original tab

# Optionally, you can wait for some time or perform other actions on the page

# Close the browser
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Cell In[8], line 40
#      31 time.sleep(15)
#      33 # Store the handle of the original tab
#      34 #original_tab = driver.current_window_handle
#      35
#    (...)
#      38
#      39 # Switch back to the original tab
# ---> 40 driver.switch_to.window(original_tab)
#      42 # Now you are back in the original tab
#      43
#      44 # Optionally, you can wait for some time or perform other actions on the page
#      45
#      46 # Close the browser
#      47 driver.quit()
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/switch_to.py:133, in SwitchTo.window(self, window_name)
#     122 def window(self, window_name: str) -> None:
#     123     """Switches focus to the specified window.
#     124
#     125     :Args:
#    (...)
#     131             driver.switch_to.window('main')
#     132     """
# --> 133     self._w3c_window(window_name)
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/switch_to.py:141, in SwitchTo._w3c_window(self, window_name)
#     137     self._driver.execute(Command.SWITCH_TO_WINDOW, {"handle": h})
#     139 try:
#     140     # Try using it as a handle first.
# --> 141     send_handle(window_name)
#     142 except NoSuchWindowException:
#     143     # Check every window to try to find the given window name.
#     144     original_handle = self._driver.current_window_handle
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/switch_to.py:137, in SwitchTo._w3c_window.<locals>.send_handle(h)
#     136 def send_handle(h):
# --> 137     self._driver.execute(Command.SWITCH_TO_WINDOW, {"handle": h})
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: invalid argument: 'handle' must be a string
#   (Session info: chrome=120.0.6099.71)
# Stacktrace:
# #0 0x558d3a0c9ea3 <unknown>
# #1 0x558d39d95297 <unknown>
# #2 0x558d39e1c319 <unknown>
# #3 0x558d39e0d208 <unknown>
# #4 0x558d39dd55a3 <unknown>
# #5 0x558d39dd696e <unknown>
# #6 0x558d3a09184d <unknown>
# #7 0x558d3a095774 <unknown>
# #8 0x558d3a080cc2 <unknown>
# #9 0x558d3a096235 <unknown>
# #10 0x558d3a0674de <unknown>
# #11 0x558d3a0b80d8 <unknown>
# #12 0x558d3a0b82e1 <unknown>
# #13 0x558d3a0c8fe5 <unknown>
# #14 0x7f780c406ac3 <unknown>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time

chromedriver_path = "/usr/bin/chromedriver"
data_miner_extension_path = "datascraper.crx"

# Set up Chrome options
options = Options()
options.add_extension(data_miner_extension_path)

# Set up the ChromeDriver service
service = Service(executable_path=chromedriver_path)

# Create a WebDriver instance
#driver = webdriver.Chrome(service=service, options=options)
# Open Google's homepage

# Disable pop-ups
prefs = {"profile.default_content_setting_values.notifications": 2}
options.add_experimental_option("prefs", prefs)

# Create a WebDriver instance
driver = webdriver.Chrome(service=service, options=options)

# Open Google's homepage
driver.get("https://www.google.com/")

# Find the search input element by name
search_box = driver.find_element("name", "q")

# Enter your search query
search_box.send_keys('Salesforce Developer india opentowork "gmail com" site:linkedin.com 1..100')

# Press the Enter key
search_box.send_keys(Keys.RETURN)

# Wait for the results to load (adjust the sleep duration as needed)
time.sleep(15)

# Now you can perform other actions in the current tab without opening the unwanted URL

# Close the browser
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
from selenium.webdriver.common.action_chains import ActionChains

chromedriver_path = "/usr/bin/chromedriver"
data_miner_extension_path = "datascraper.crx"

options = Options()
options.add_extension(data_miner_extension_path)


service = Service(executable_path=chromedriver_path)

prefs = {"profile.default_content_setting_values.notifications": 2}
options.add_experimental_option("prefs", prefs)

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.google.com/")

search_box = driver.find_element("name", "q")

search_box.send_keys('Salesforce Developer india opentowork "gmail com" site:linkedin.com 1..100')

search_box.send_keys(Keys.RETURN)

time.sleep(15)

action_chains = ActionChains(driver)
action_chains.context_click(search_box).perform()

time.sleep(5)

action_chains.send_keys(Keys.ARROW_DOWN).send_keys(Keys.ENTER).perform()

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[14], line 32
#      29 time.sleep(15)
#      31 action_chains = ActionChains(driver)
# ---> 32 action_chains.context_click(search_box).perform()
#      34 time.sleep(5)
#      36 action_chains.send_keys(Keys.ARROW_DOWN).send_keys(Keys.ENTER).perform()
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/common/action_chains.py:94, in ActionChains.perform(self)
#      92 def perform(self) -> None:
#      93     """Performs all stored actions."""
# ---> 94     self.w3c_actions.perform()
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/common/actions/action_builder.py:96, in ActionBuilder.perform(self)
#      94         enc["actions"].append(encoded)
#      95         device.actions = []
# ---> 96 self.driver.execute(Command.W3C_ACTIONS, enc)
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=120.0.6099.71); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# #0 0x5619a7d31ea3 <unknown>
# #1 0x5619a79fd297 <unknown>
# #2 0x5619a7a0ed70 <unknown>
# #3 0x5619a7a042d4 <unknown>
# #4 0x5619a7a0212d <unknown>
# #5 0x5619a7a05d18 <unknown>
# #6 0x5619a7a05e6c <unknown>
# #7 0x5619a7a536fa <unknown>
# #8 0x5619a7a528e0 <unknown>
# #9 0x5619a7a9d6f0 <unknown>
# #10 0x5619a7a75242 <unknown>
# #11 0x5619a7a93c2a <unknown>
# #12 0x5619a7a74fe3 <unknown>
# #13 0x5619a7a3d5a3 <unknown>
# #14 0x5619a7a3e96e <unknown>
# #15 0x5619a7cf984d <unknown>
# #16 0x5619a7cfd774 <unknown>
# #17 0x5619a7ce8cc2 <unknown>
# #18 0x5619a7cfe235 <unknown>
# #19 0x5619a7ccf4de <unknown>
# #20 0x5619a7d200d8 <unknown>
# #21 0x5619a7d202e1 <unknown>
# #22 0x5619a7d30fe5 <unknown>
# #23 0x7f5284539ac3 <unknown>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = "/usr/bin/chromedriver"
data_miner_extension_path = "datascraper.crx"

options = Options()
options.add_extension(data_miner_extension_path)
service = Service(executable_path=chromedriver_path)

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.google.com/")

search_box = driver.find_element("name", "q")

search_box.send_keys('Salesforce Developer india opentowork "gmail com" site:linkedin.com 1..100')

search_box.send_keys(Keys.RETURN)

time.sleep(15)

# Store the current window handle (the original tab)
original_tab = driver.current_window_handle

action_chains = ActionChains(driver)
action_chains.context_click(search_box).perform()

time.sleep(5)

# Perform actions to open a new tab (you may need to modify this part based on your extension behavior)
action_chains.send_keys(Keys.ARROW_DOWN).send_keys(Keys.ENTER).perform()

# Switch to the new tab
for handle in driver.window_handles:
    if handle != original_tab:
        driver.switch_to.window(handle)

# Close the new tab
driver.close()

# Switch back to the original tab
driver.switch_to.window(original_tab)

# Now, you are back in the original tab

# Continue with the rest of your code or quit the driver
# driver.quit()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[16], line 30
#      27 original_tab = driver.current_window_handle
#      29 action_chains = ActionChains(driver)
# ---> 30 action_chains.context_click(search_box).perform()
#      32 time.sleep(5)
#      34 # Perform actions to open a new tab (you may need to modify this part based on your extension behavior)
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/common/action_chains.py:94, in ActionChains.perform(self)
#      92 def perform(self) -> None:
#      93     """Performs all stored actions."""
# ---> 94     self.w3c_actions.perform()
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/common/actions/action_builder.py:96, in ActionBuilder.perform(self)
#      94         enc["actions"].append(encoded)
#      95         device.actions = []
# ---> 96 self.driver.execute(Command.W3C_ACTIONS, enc)
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~/Documents/applications/talent_iq/notebooks/tiq-notebooks/linkedin_profile/.python3.10/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=120.0.6099.71); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# #0 0x5633ed58cea3 <unknown>
# #1 0x5633ed258297 <unknown>
# #2 0x5633ed269d70 <unknown>
# #3 0x5633ed25f2d4 <unknown>
# #4 0x5633ed25d12d <unknown>
# #5 0x5633ed260d18 <unknown>
# #6 0x5633ed260e6c <unknown>
# #7 0x5633ed2ae6fa <unknown>
# #8 0x5633ed2ad8e0 <unknown>
# #9 0x5633ed2f86f0 <unknown>
# #10 0x5633ed2d0242 <unknown>
# #11 0x5633ed2eec2a <unknown>
# #12 0x5633ed2cffe3 <unknown>
# #13 0x5633ed2985a3 <unknown>
# #14 0x5633ed29996e <unknown>
# #15 0x5633ed55484d <unknown>
# #16 0x5633ed558774 <unknown>
# #17 0x5633ed543cc2 <unknown>
# #18 0x5633ed559235 <unknown>
# #19 0x5633ed52a4de <unknown>
# #20 0x5633ed57b0d8 <unknown>
# #21 0x5633ed57b2e1 <unknown>
# #22 0x5633ed58bfe5 <unknown>
# #23 0x7f835f312ac3 <unknown>
